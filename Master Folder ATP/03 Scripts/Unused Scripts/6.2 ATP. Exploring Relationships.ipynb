# %% [markdown]
# # 6.2: Exploring Relationships (ATP Data)

# %% [markdown]
# ## 1. Importing Data and Libraries
# ## 2. df_matchstats
# #### 2a. Cleaning
# #### 2b. Correlation Heatmap
# #### 2c. Scatterplot
# #### 2d. Pair Plot
# #### 2e. Categorical Plot
# ## 3. df_BO5
# #### 3a. Cleaning
# #### 3b. Correlation Heatmap
# #### 3c. Scatterplot
# #### 3d. Pair Plot
# #### 3e. Categorical Plot
# ## 4. df_BO3
# #### 4a. Cleaning
# #### 4b. Correlation Heatmap
# #### 4c. Scatterplot
# #### 4d. Pair Plot
# #### 4e. Categorical Plot
# ## 5. df_big3_win_BO5
# #### 5a. Cleaning
# #### 5b. Correlation Heatmap
# #### 5c. Scatterplot
# #### 5d. Pair Plot
# #### 8e. Categorical Plot
# ## 6. df_big3_lose_BO5
# #### 6a. Cleaning
# #### 6b. Correlation Heatmap
# #### 6c. Scatterplot
# #### 6d. Pair Plot
# #### 6e. Categorical Plot
# ## 7. df_grass
# #### 7a. Cleaning
# #### 7b. Correlation Heatmap
# #### 7c. Scatterplot
# #### 7d. Pair Plot
# #### 7e. Categorical Plot
# ## 8. df_clay
# #### 8a. Cleaning
# #### 8b. Correlation Heatmap
# #### 8c. Scatterplot
# #### 8d. Pair Plot
# #### 8e. Categorical Plot
# ## 9. df_hard
# #### 9a. Cleaning
# #### 9b. Correlation Heatmap
# #### 9c. Scatterplot
# #### 9d. Pair Plot
# #### 9e. Categorical Plot
# ## 10. Initial Insights

# %% [markdown]
# # 1. Importing Data and Libraries

# %%
#Set Path
path = r'/Users/tristansavella/Desktop/Important Things/Data Analytics/CareerFoundry/Data Immersion/Achievement 6/Master Folder ATP/02 Data'

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy
import matplotlib

# %% [markdown]
# # 2. df_matchstats

# %%
#Import df_matchstats
df_matchstats = pd.read_pickle(os.path.join(path, 'Prepared Data','df_matchstats.pkl'))

# %%
#Show all columns
pd.set_option('display.max_columns', None)

# %%
#Show all rows
pd.set_option('display.max_rows', None)

# %%
#check head
df_matchstats.head()
# Out:
#       tourney_id  Year tourney_name surface tourney_level winner_id  \
# 85848   1991-339  1990     Adelaide    Hard             A    101723
# 85849   1991-339  1990     Adelaide    Hard             A    100946
# 85850   1991-339  1990     Adelaide    Hard             A    101234
# 85851   1991-339  1990     Adelaide    Hard             A    101889
# 85852   1991-339  1990     Adelaide    Hard             A    101274
#
#       winner_ioc           winner_name  winner_age  winner_rank loser_id  \
# 85848        SWE        Magnus Larsson        20.7         56.0   101414
# 85849        YUG  Slobodan Zivojinovic        27.4        304.0   101256
# 85850        GER         Patrik Kuhnen        24.8         82.0   101421
# 85851        AUS       Todd Woodbridge        19.7         50.0   101703
# 85852        GER         Udo Riglewski        24.4         88.0   101843
#
#       loser_ioc       loser_name  loser_rank  loser_age best_of round  \
# 85848       GER     Boris Becker         2.0       23.1       3   R32
# 85849       AUS   Mark Kratzmann        75.0       24.6       3   R32
# 85850       FIN   Veli Paloheimo        69.0       23.0       3   R32
# 85851       FRA  Guillaume Raoux        84.0       20.8       3   R32
# 85852       ESP   Sergi Bruguera        28.0       19.9       3   R32
#
#        minutes  w_#ServeGames  w_#aces  w_#dfs  w_#ServePoints  \
# 85848    130.0           15.0      6.0     2.0            96.0
# 85849    119.0           15.0     19.0     4.0           101.0
# 85850     71.0            8.0      6.0     1.0            54.0
# 85851     85.0            9.0      2.0     0.0            60.0
# 85852     90.0           10.0      4.0     2.0            72.0
#
#        w_#1stServesIn  w_#2ndServePoints  w_%1stServesIn  w_#1stWon  \
# 85848            55.0               41.0              57       39.0
# 85849            56.0               45.0              55       45.0
# 85850            31.0               23.0              57       24.0
# 85851            40.0               20.0              66       30.0
# 85852            40.0               32.0              55       33.0
#
#        w_%1stWon  w_#2ndWon  w_%2ndWon  w_bpSaved  w_#bpFaced  l_#ServeGames  \
# 85848         70       25.0         60        2.0         4.0           16.0
# 85849         80       25.0         55        9.0        10.0           15.0
# 85850         77       13.0         56        1.0         1.0            8.0
# 85851         75       14.0         70        3.0         3.0           10.0
# 85852         82       14.0         43        7.0         8.0           11.0
#
#        l_#aces  l_#dfs  l_#ServePoints  l_#1stServesIn  l_#2ndServePoints  \
# 85848      8.0     3.0            95.0            62.0               33.0
# 85849      8.0     2.0            84.0            41.0               43.0
# 85850      2.0     2.0            60.0            37.0               23.0
# 85851      3.0     3.0            74.0            45.0               29.0
# 85852      2.0     2.0            77.0            41.0               36.0
#
#        l_%1stServesIn  l_#1stWon  l_%1stWon  l_#2ndWon  l_%2ndWon  l_bpSaved  \
# 85848              65       44.0         70       23.0         69        6.0
# 85849              48       35.0         85       27.0         62        1.0
# 85850              61       22.0         59        6.0         26        4.0
# 85851              60       30.0         66       11.0         37        5.0
# 85852              53       28.0         68       15.0         41        4.0
#
#        l_#bpFaced
# 85848         8.0
# 85849         2.0
# 85850         8.0
# 85851         8.0
# 85852         8.0

# %% [markdown]
# ## 2a. Cleaning

# %%
df_matchstats.shape
# Out:
# (92161, 44)

# %%
df_matchstats.columns
# Out:
# Index(['tourney_id', 'Year', 'tourney_name', 'surface', 'tourney_level',
#        'winner_id', 'winner_ioc', 'winner_name', 'winner_age', 'winner_rank',
#        'loser_id', 'loser_ioc', 'loser_name', 'loser_rank', 'loser_age',
#        'best_of', 'round', 'minutes', 'w_#ServeGames', 'w_#aces', 'w_#dfs',
#        'w_#ServePoints', 'w_#1stServesIn', 'w_#2ndServePoints',
#        'w_%1stServesIn', 'w_#1stWon', 'w_%1stWon', 'w_#2ndWon', 'w_%2ndWon',
#        'w_bpSaved', 'w_#bpFaced', 'l_#ServeGames', 'l_#aces', 'l_#dfs',
#        'l_#ServePoints', 'l_#1stServesIn', 'l_#2ndServePoints',
#        'l_%1stServesIn', 'l_#1stWon', 'l_%1stWon', 'l_#2ndWon', 'l_%2ndWon',
#        'l_bpSaved', 'l_#bpFaced'],
#       dtype='object')

# %%
df_matchstats.dtypes
# Out:
# tourney_id            object
# Year                  object
# tourney_name          object
# surface               object
# tourney_level         object
# winner_id             object
# winner_ioc            object
# winner_name           object
# winner_age           float64
# winner_rank          float64
# loser_id              object
# loser_ioc             object
# loser_name            object
# loser_rank           float64
# loser_age            float64
# best_of               object
# round                 object
# minutes              float64
# w_#ServeGames        float64
# w_#aces              float64
# w_#dfs               float64
# w_#ServePoints       float64
# w_#1stServesIn       float64
# w_#2ndServePoints    float64
# w_%1stServesIn         int64
# w_#1stWon            float64
# w_%1stWon              int64
# w_#2ndWon            float64
# w_%2ndWon              int64
# w_bpSaved            float64
# w_#bpFaced           float64
# l_#ServeGames        float64
# l_#aces              float64
# l_#dfs               float64
# l_#ServePoints       float64
# l_#1stServesIn       float64
# l_#2ndServePoints    float64
# l_%1stServesIn         int64
# l_#1stWon            float64
# l_%1stWon              int64
# l_#2ndWon            float64
# l_%2ndWon              int64
# l_bpSaved            float64
# l_#bpFaced           float64
# dtype: object

# %%
# Check for missing values

df_matchstats.isnull().sum() #will disregard data pertaining to 'winner_rank', 'loser_rank' and 'minutes'
# Out:
# tourney_id              0
# Year                    0
# tourney_name            0
# surface                 0
# tourney_level           0
# winner_id               0
# winner_ioc              0
# winner_name             0
# winner_age              0
# winner_rank           276
# loser_id                0
# loser_ioc               0
# loser_name              0
# loser_rank            603
# loser_age              19
# best_of                 0
# round                   0
# minutes              2755
# w_#ServeGames           0
# w_#aces                 0
# w_#dfs                  0
# w_#ServePoints          0
# w_#1stServesIn          0
# w_#2ndServePoints       0
# w_%1stServesIn          0
# w_#1stWon               0
# w_%1stWon               0
# w_#2ndWon               0
# w_%2ndWon               0
# w_bpSaved               0
# w_#bpFaced              0
# l_#ServeGames           0
# l_#aces                 0
# l_#dfs                  0
# l_#ServePoints          0
# l_#1stServesIn          0
# l_#2ndServePoints       0
# l_%1stServesIn          0
# l_#1stWon               0
# l_%1stWon               0
# l_#2ndWon               0
# l_%2ndWon               0
# l_bpSaved               0
# l_#bpFaced              0
# dtype: int64

# %%
# Find duplicates

df_dups = df_matchstats[df_matchstats.duplicated()]

# %%
df_dups.shape #no duplicates
# Out:
# (0, 44)

# %%
for col in df_matchstats.columns.tolist():
      weird = (df_matchstats[[col]].applymap(type) != df_matchstats[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df_matchstats[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %%
df_matchstats.head()
# Out:
#       tourney_id  Year tourney_name surface tourney_level winner_id  \
# 85848   1991-339  1990     Adelaide    Hard             A    101723
# 85849   1991-339  1990     Adelaide    Hard             A    100946
# 85850   1991-339  1990     Adelaide    Hard             A    101234
# 85851   1991-339  1990     Adelaide    Hard             A    101889
# 85852   1991-339  1990     Adelaide    Hard             A    101274
#
#       winner_ioc           winner_name  winner_age  winner_rank loser_id  \
# 85848        SWE        Magnus Larsson        20.7         56.0   101414
# 85849        YUG  Slobodan Zivojinovic        27.4        304.0   101256
# 85850        GER         Patrik Kuhnen        24.8         82.0   101421
# 85851        AUS       Todd Woodbridge        19.7         50.0   101703
# 85852        GER         Udo Riglewski        24.4         88.0   101843
#
#       loser_ioc       loser_name  loser_rank  loser_age best_of round  \
# 85848       GER     Boris Becker         2.0       23.1       3   R32
# 85849       AUS   Mark Kratzmann        75.0       24.6       3   R32
# 85850       FIN   Veli Paloheimo        69.0       23.0       3   R32
# 85851       FRA  Guillaume Raoux        84.0       20.8       3   R32
# 85852       ESP   Sergi Bruguera        28.0       19.9       3   R32
#
#        minutes  w_#ServeGames  w_#aces  w_#dfs  w_#ServePoints  \
# 85848    130.0           15.0      6.0     2.0            96.0
# 85849    119.0           15.0     19.0     4.0           101.0
# 85850     71.0            8.0      6.0     1.0            54.0
# 85851     85.0            9.0      2.0     0.0            60.0
# 85852     90.0           10.0      4.0     2.0            72.0
#
#        w_#1stServesIn  w_#2ndServePoints  w_%1stServesIn  w_#1stWon  \
# 85848            55.0               41.0              57       39.0
# 85849            56.0               45.0              55       45.0
# 85850            31.0               23.0              57       24.0
# 85851            40.0               20.0              66       30.0
# 85852            40.0               32.0              55       33.0
#
#        w_%1stWon  w_#2ndWon  w_%2ndWon  w_bpSaved  w_#bpFaced  l_#ServeGames  \
# 85848         70       25.0         60        2.0         4.0           16.0
# 85849         80       25.0         55        9.0        10.0           15.0
# 85850         77       13.0         56        1.0         1.0            8.0
# 85851         75       14.0         70        3.0         3.0           10.0
# 85852         82       14.0         43        7.0         8.0           11.0
#
#        l_#aces  l_#dfs  l_#ServePoints  l_#1stServesIn  l_#2ndServePoints  \
# 85848      8.0     3.0            95.0            62.0               33.0
# 85849      8.0     2.0            84.0            41.0               43.0
# 85850      2.0     2.0            60.0            37.0               23.0
# 85851      3.0     3.0            74.0            45.0               29.0
# 85852      2.0     2.0            77.0            41.0               36.0
#
#        l_%1stServesIn  l_#1stWon  l_%1stWon  l_#2ndWon  l_%2ndWon  l_bpSaved  \
# 85848              65       44.0         70       23.0         69        6.0
# 85849              48       35.0         85       27.0         62        1.0
# 85850              61       22.0         59        6.0         26        4.0
# 85851              60       30.0         66       11.0         37        5.0
# 85852              53       28.0         68       15.0         41        4.0
#
#        l_#bpFaced
# 85848         8.0
# 85849         2.0
# 85850         8.0
# 85851         8.0
# 85852         8.0

# %% [markdown]
# ## 2B. Correlation Heatmap

# %%
#create subset: drop irrelevant variables

df_matchstats1 = df_matchstats.drop(columns = ['tourney_id',
                                               'Year',
                                              'tourney_name',
                                              'surface',
                                               'tourney_level',
                                              'winner_id',
                                               'winner_name',
                                               'winner_ioc',
                                               'winner_age',
                                               'winner_rank',
                                               'loser_id', 
                                               'loser_name',
                                               'loser_ioc',
                                               'loser_rank',
                                               'loser_age',
                                               'best_of',
                                               'round',
                                               'minutes'])

# %%
df_matchstats1.corr()
# There are way too many variables to cleanly present on a heatmap; divide into following - 
# keep mostly "percentage" variables to reduce dataset size
# Out:
#                    w_#ServeGames   w_#aces    w_#dfs  w_#ServePoints  \
# w_#ServeGames           1.000000  0.415332  0.439142        0.942540
# w_#aces                 0.415332  1.000000  0.262281        0.364339
# w_#dfs                  0.439142  0.262281  1.000000        0.492874
# w_#ServePoints          0.942540  0.364339  0.492874        1.000000
# w_#1stServesIn          0.893267  0.326203  0.359281        0.936692
# w_#2ndServePoints       0.799060  0.336358  0.573076        0.863653
# w_%1stServesIn          0.017063 -0.039917 -0.268268       -0.010217
# w_#1stWon               0.898203  0.465012  0.381462        0.909306
# w_%1stWon              -0.161565  0.354179 -0.013244       -0.277581
# w_#2ndWon               0.743361  0.321036  0.416320        0.757665
# w_%2ndWon              -0.209250 -0.068828 -0.379116       -0.319946
# w_bpSaved               0.440237  0.056694  0.331027        0.611349
# w_#bpFaced              0.553549  0.023875  0.387369        0.692522
# l_#ServeGames           0.985736  0.401783  0.436365        0.933323
# l_#aces                 0.499410  0.316411  0.196584        0.454217
# l_#dfs                  0.338742  0.125126  0.252693        0.329569
# l_#ServePoints          0.927057  0.362171  0.419538        0.895158
# l_#1stServesIn          0.875299  0.358620  0.369280        0.841871
# l_#2ndServePoints       0.774469  0.278343  0.389472        0.752630
# l_%1stServesIn          0.096491  0.072976 -0.023501        0.085285
# l_#1stWon               0.897374  0.430027  0.377764        0.859924
# l_%1stWon               0.363046  0.313796  0.152810        0.339541
# l_#2ndWon               0.773550  0.353895  0.373262        0.745802
# l_%2ndWon               0.284687  0.254587  0.112252        0.267692
# l_bpSaved               0.365083  0.057750  0.173028        0.347662
# l_#bpFaced              0.379145 -0.028951  0.192952        0.363202
#
#                    w_#1stServesIn  w_#2ndServePoints  w_%1stServesIn  \
# w_#ServeGames            0.893267           0.799060        0.017063
# w_#aces                  0.326203           0.336358       -0.039917
# w_#dfs                   0.359281           0.573076       -0.268268
# w_#ServePoints           0.936692           0.863653       -0.010217
# w_#1stServesIn           1.000000           0.632469        0.316776
# w_#2ndServePoints        0.632469           1.000000       -0.478638
# w_%1stServesIn           0.316776          -0.478638        1.000000
# w_#1stWon                0.960386           0.628916        0.285454
# w_%1stWon               -0.315659          -0.159617       -0.158908
# w_#2ndWon                0.529786           0.913367       -0.500803
# w_%2ndWon               -0.295924          -0.281746        0.007109
# w_bpSaved                0.557571           0.549695       -0.043789
# w_#bpFaced               0.627903           0.628010       -0.059414
# l_#ServeGames            0.884134           0.791818        0.015618
# l_#aces                  0.442449           0.367831        0.035046
# l_#dfs                   0.284955           0.318823       -0.069572
# l_#ServePoints           0.847358           0.760335        0.013129
# l_#1stServesIn           0.816501           0.686881        0.061450
# l_#2ndServePoints        0.683988           0.680235       -0.060303
# l_%1stServesIn           0.127776           0.004713        0.133992
# l_#1stWon                0.832282           0.704099        0.057127
# l_%1stWon                0.320278           0.290033        0.001646
# l_#2ndWon                0.681237           0.669092       -0.049894
# l_%2ndWon                0.251086           0.230702        0.000954
# l_bpSaved                0.325260           0.300824       -0.005574
# l_#bpFaced               0.334915           0.321302       -0.017736
#
#                    w_#1stWon  w_%1stWon  w_#2ndWon  w_%2ndWon  w_bpSaved  \
# w_#ServeGames       0.898203  -0.161565   0.743361  -0.209250   0.440237
# w_#aces             0.465012   0.354179   0.321036  -0.068828   0.056694
# w_#dfs              0.381462  -0.013244   0.416320  -0.379116   0.331027
# w_#ServePoints      0.909306  -0.277581   0.757665  -0.319946   0.611349
# w_#1stServesIn      0.960386  -0.315659   0.529786  -0.295924   0.557571
# w_#2ndServePoints   0.628916  -0.159617   0.913367  -0.281746   0.549695
# w_%1stServesIn      0.285454  -0.158908  -0.500803   0.007109  -0.043789
# w_#1stWon           1.000000  -0.063410   0.526799  -0.290252   0.460583
# w_%1stWon          -0.063410   1.000000  -0.138964   0.086549  -0.407726
# w_#2ndWon           0.526799  -0.138964   1.000000   0.087347   0.412933
# w_%2ndWon          -0.290252   0.086549   0.087347   1.000000  -0.349315
# w_bpSaved           0.460583  -0.407726   0.412933  -0.349315   1.000000
# w_#bpFaced          0.496107  -0.530509   0.448820  -0.444582   0.939789
# l_#ServeGames       0.885346  -0.172376   0.733247  -0.214102   0.440464
# l_#aces             0.499332   0.075135   0.406798   0.021003   0.126894
# l_#dfs              0.283942  -0.060214   0.285807  -0.099357   0.166531
# l_#ServePoints      0.846376  -0.171816   0.698644  -0.212843   0.420348
# l_#1stServesIn      0.818206  -0.155793   0.630352  -0.195720   0.389117
# l_#2ndServePoints   0.679341  -0.152879   0.626202  -0.185424   0.362440
# l_%1stServesIn      0.133685  -0.007373   0.001592  -0.011818   0.025190
# l_#1stWon           0.861838  -0.077464   0.673201  -0.148065   0.363788
# l_%1stWon           0.392556   0.162701   0.341140   0.059289   0.074632
# l_#2ndWon           0.699171  -0.085118   0.641450  -0.139189   0.335052
# l_%2ndWon           0.294941   0.082003   0.261714   0.017120   0.082293
# l_bpSaved           0.295317  -0.149383   0.252314  -0.131805   0.207248
# l_#bpFaced          0.266066  -0.269177   0.231579  -0.212007   0.261539
#
#                    w_#bpFaced  l_#ServeGames   l_#aces    l_#dfs  \
# w_#ServeGames        0.553549       0.985736  0.499410  0.338742
# w_#aces              0.023875       0.401783  0.316411  0.125126
# w_#dfs               0.387369       0.436365  0.196584  0.252693
# w_#ServePoints       0.692522       0.933323  0.454217  0.329569
# w_#1stServesIn       0.627903       0.884134  0.442449  0.284955
# w_#2ndServePoints    0.628010       0.791818  0.367831  0.318823
# w_%1stServesIn      -0.059414       0.015618  0.035046 -0.069572
# w_#1stWon            0.496107       0.885346  0.499332  0.283942
# w_%1stWon           -0.530509      -0.172376  0.075135 -0.060214
# w_#2ndWon            0.448820       0.733247  0.406798  0.285807
# w_%2ndWon           -0.444582      -0.214102  0.021003 -0.099357
# w_bpSaved            0.939789       0.440464  0.126894  0.166531
# w_#bpFaced           1.000000       0.557110  0.126018  0.217926
# l_#ServeGames        0.557110       1.000000  0.502259  0.347283
# l_#aces              0.126018       0.502259  1.000000  0.265861
# l_#dfs               0.217926       0.347283  0.265861  1.000000
# l_#ServePoints       0.535834       0.940287  0.467557  0.396316
# l_#1stServesIn       0.493020       0.886074  0.412265  0.247255
# l_#2ndServePoints    0.466378       0.788017  0.433006  0.515507
# l_%1stServesIn       0.026006       0.093208 -0.023017 -0.286265
# l_#1stWon            0.438490       0.904793  0.558153  0.296902
# l_%1stWon            0.032520       0.354722  0.532793  0.226296
# l_#2ndWon            0.408294       0.781975  0.431621  0.352407
# l_%2ndWon            0.058544       0.277015  0.154161 -0.151646
# l_bpSaved            0.283341       0.374382  0.108486  0.247680
# l_#bpFaced           0.387796       0.395405  0.000512  0.274382
#
#                    l_#ServePoints  l_#1stServesIn  l_#2ndServePoints  \
# w_#ServeGames            0.927057        0.875299           0.774469
# w_#aces                  0.362171        0.358620           0.278343
# w_#dfs                   0.419538        0.369280           0.389472
# w_#ServePoints           0.895158        0.841871           0.752630
# w_#1stServesIn           0.847358        0.816501           0.683988
# w_#2ndServePoints        0.760335        0.686881           0.680235
# w_%1stServesIn           0.013129        0.061450          -0.060303
# w_#1stWon                0.846376        0.818206           0.679341
# w_%1stWon               -0.171816       -0.155793          -0.152879
# w_#2ndWon                0.698644        0.630352           0.626202
# w_%2ndWon               -0.212843       -0.195720          -0.185424
# w_bpSaved                0.420348        0.389117           0.362440
# w_#bpFaced               0.535834        0.493020           0.466378
# l_#ServeGames            0.940287        0.886074           0.788017
# l_#aces                  0.467557        0.412265           0.433006
# l_#dfs                   0.396316        0.247255           0.515507
# l_#ServePoints           1.000000        0.932792           0.851937
# l_#1stServesIn           0.932792        1.000000           0.605951
# l_#2ndServePoints        0.851937        0.605951           1.000000
# l_%1stServesIn           0.078560        0.408955          -0.420770
# l_#1stWon                0.921374        0.952907           0.649172
# l_%1stWon                0.285450        0.201575           0.337173
# l_#2ndWon                0.798503        0.591004           0.903777
# l_%2ndWon                0.207718        0.203227           0.163205
# l_bpSaved                0.551580        0.503696           0.485622
# l_#bpFaced               0.541297        0.484860           0.490292
#
#                    l_%1stServesIn  l_#1stWon  l_%1stWon  l_#2ndWon  l_%2ndWon  \
# w_#ServeGames            0.096491   0.897374   0.363046   0.773550   0.284687
# w_#aces                  0.072976   0.430027   0.313796   0.353895   0.254587
# w_#dfs                  -0.023501   0.377764   0.152810   0.373262   0.112252
# w_#ServePoints           0.085285   0.859924   0.339541   0.745802   0.267692
# w_#1stServesIn           0.127776   0.832282   0.320278   0.681237   0.251086
# w_#2ndServePoints        0.004713   0.704099   0.290033   0.669092   0.230702
# w_%1stServesIn           0.133992   0.057127   0.001646  -0.049894   0.000954
# w_#1stWon                0.133685   0.861838   0.392556   0.699171   0.294941
# w_%1stWon               -0.007373  -0.077464   0.162701  -0.085118   0.082003
# w_#2ndWon                0.001592   0.673201   0.341140   0.641450   0.261714
# w_%2ndWon               -0.011818  -0.148065   0.059289  -0.139189   0.017120
# w_bpSaved                0.025190   0.363788   0.074632   0.335052   0.082293
# w_#bpFaced               0.026006   0.438490   0.032520   0.408294   0.058544
# l_#ServeGames            0.093208   0.904793   0.354722   0.781975   0.277015
# l_#aces                 -0.023017   0.558153   0.532793   0.431621   0.154161
# l_#dfs                  -0.286265   0.296902   0.226296   0.352407  -0.151646
# l_#ServePoints           0.078560   0.921374   0.285450   0.798503   0.207718
# l_#1stServesIn           0.408955   0.952907   0.201575   0.591004   0.203227
# l_#2ndServePoints       -0.420770   0.649172   0.337173   0.903777   0.163205
# l_%1stServesIn           1.000000   0.310725  -0.156052  -0.330758   0.046880
# l_#1stWon                0.310725   1.000000   0.461378   0.629587   0.211067
# l_%1stWon               -0.156052   0.461378   1.000000   0.324515   0.132029
# l_#2ndWon               -0.330758   0.629587   0.324515   1.000000   0.531717
# l_%2ndWon                0.046880   0.211067   0.132029   0.531717   1.000000
# l_bpSaved                0.016835   0.415260  -0.070657   0.375101  -0.049192
# l_#bpFaced              -0.011014   0.338357  -0.261270   0.309829  -0.203616
#
#                    l_bpSaved  l_#bpFaced
# w_#ServeGames       0.365083    0.379145
# w_#aces             0.057750   -0.028951
# w_#dfs              0.173028    0.192952
# w_#ServePoints      0.347662    0.363202
# w_#1stServesIn      0.325260    0.334915
# w_#2ndServePoints   0.300824    0.321302
# w_%1stServesIn     -0.005574   -0.017736
# w_#1stWon           0.295317    0.266066
# w_%1stWon          -0.149383   -0.269177
# w_#2ndWon           0.252314    0.231579
# w_%2ndWon          -0.131805   -0.212007
# w_bpSaved           0.207248    0.261539
# w_#bpFaced          0.283341    0.387796
# l_#ServeGames       0.374382    0.395405
# l_#aces             0.108486    0.000512
# l_#dfs              0.247680    0.274382
# l_#ServePoints      0.551580    0.541297
# l_#1stServesIn      0.503696    0.484860
# l_#2ndServePoints   0.485622    0.490292
# l_%1stServesIn      0.016835   -0.011014
# l_#1stWon           0.415260    0.338357
# l_%1stWon          -0.070657   -0.261270
# l_#2ndWon           0.375101    0.309829
# l_%2ndWon          -0.049192   -0.203616
# l_bpSaved           1.000000    0.921985
# l_#bpFaced          0.921985    1.000000

# %%
df_matchstats2 = df_matchstats1.drop(columns = ['w_#ServeGames', 
                                                        'w_#aces',
                                                        'w_#dfs',
                                                        'w_#1stServesIn',
                                                        'w_#2ndServePoints',
                                                        'w_#1stWon',
                                                        'w_#2ndWon',
                                                        'w_bpSaved',
                                                        'l_#ServeGames',
                                                        'l_#aces',
                                                        'l_#dfs',
                                                        'l_#1stServesIn', 
                                                        'l_#2ndServePoints', 
                                                        'l_#1stWon',
                                                        'l_#2ndWon',
                                                        'l_bpSaved'])

# %%
df_matchstats2.describe()
# Out:
#        w_#ServePoints  w_%1stServesIn     w_%1stWon     w_%2ndWon  \
# count    92161.000000    92161.000000  92161.000000  92161.000000
# mean        78.087749       60.508208     76.001411     55.757576
# std         29.502217        8.599488      8.345894     10.531948
# min          3.000000       12.000000      0.000000      0.000000
# 25%         56.000000       55.000000     70.000000     50.000000
# 50%         73.000000       60.000000     76.000000     55.000000
# 75%         94.000000       66.000000     82.000000     62.000000
# max        491.000000       98.000000    100.000000    129.000000
#
#          w_#bpFaced  l_#ServePoints  l_%1stServesIn     l_%1stWon  \
# count  92161.000000    92161.000000    92161.000000  92161.000000
# mean       5.168726       80.951259       58.619807     65.178752
# std        4.062543       29.406380        8.678656      9.772017
# min        0.000000        3.000000       12.000000      0.000000
# 25%        2.000000       59.000000       53.000000     59.000000
# 50%        4.000000       76.000000       59.000000     66.000000
# 75%        7.000000       97.000000       64.000000     72.000000
# max       34.000000      489.000000       97.000000    100.000000
#
#           l_%2ndWon    l_#bpFaced
# count  92161.000000  92161.000000
# mean      44.451102      8.747550
# std       10.260767      4.128261
# min        0.000000      0.000000
# 25%       38.000000      6.000000
# 50%       45.000000      8.000000
# 75%       51.000000     11.000000
# max      100.000000     38.000000

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(df_matchstats2.corr())
plt.show()

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(df_matchstats2.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df_matchstats2.corr(), fignum=f.number) # type of plot
plt.xticks(range(df_matchstats2.shape[1]), df_matchstats2, fontsize=12, rotation=90) # x axis labels
plt.yticks(range(df_matchstats2.shape[1]), df_matchstats2.columns, fontsize=12) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Serve Stats', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Serve Stats')

# %% [markdown]
# ### 2C. Scatterplots

# %%
# Create a scatterplot for the "availability_365" and "price per unit" columns in seaborn

sns.lmplot(x = 'w_%1stWon', y = 'w_#bpFaced', data = df_matchstats2)
# Out:
# /Users/tristansavella/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 2D. Pairplot

# %%
# Keep only the variables you want to use in the pair plot

df_matchstats2_pairplot = df_matchstats2[['w_%1stWon', 'w_%1stServesIn', 'w_%2ndWon','w_#bpFaced']]

# %%
# Create a pair plot 

g = sns.pairplot(df_matchstats2_pairplot)
# Out:
# /Users/tristansavella/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 2E. Categorical Plot

# %% [markdown]
# #### Using a categorical plot to compare winner and loser's stats on three variables each:
# - points won on first serve
# - points won on second serve
# - percentage of first serves in play

# %%
df_matchstats2.describe()
# Out:
#        w_#ServePoints  w_%1stServesIn     w_%1stWon     w_%2ndWon  \
# count    92161.000000    92161.000000  92161.000000  92161.000000
# mean        78.087749       60.508208     76.001411     55.757576
# std         29.502217        8.599488      8.345894     10.531948
# min          3.000000       12.000000      0.000000      0.000000
# 25%         56.000000       55.000000     70.000000     50.000000
# 50%         73.000000       60.000000     76.000000     55.000000
# 75%         94.000000       66.000000     82.000000     62.000000
# max        491.000000       98.000000    100.000000    129.000000
#
#          w_#bpFaced  l_#ServePoints  l_%1stServesIn     l_%1stWon  \
# count  92161.000000    92161.000000    92161.000000  92161.000000
# mean       5.168726       80.951259       58.619807     65.178752
# std        4.062543       29.406380        8.678656      9.772017
# min        0.000000        3.000000       12.000000      0.000000
# 25%        2.000000       59.000000       53.000000     59.000000
# 50%        4.000000       76.000000       59.000000     66.000000
# 75%        7.000000       97.000000       64.000000     72.000000
# max       34.000000      489.000000       97.000000    100.000000
#
#           l_%2ndWon    l_#bpFaced
# count  92161.000000  92161.000000
# mean      44.451102      8.747550
# std       10.260767      4.128261
# min        0.000000      0.000000
# 25%       38.000000      6.000000
# 50%       45.000000      8.000000
# 75%       51.000000     11.000000
# max      100.000000     38.000000

# %% [markdown]
# ### Percentage of first serve points won

# %%
# Use a histogram to visualize the distribution of the variables. 

sns.histplot(df_matchstats2['w_%1stWon'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='w_%1stWon', ylabel='Count'>

# %%
sns.histplot(df_matchstats2['l_%1stWon'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='l_%1stWon', ylabel='Count'>

# %% [markdown]
# ### Percentage of second serve points won

# %%
sns.histplot(df_matchstats2['w_%2ndWon'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='w_%2ndWon', ylabel='Count'>

# %%
sns.histplot(df_matchstats2['l_%2ndWon'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='l_%2ndWon', ylabel='Count'>

# %% [markdown]
# ### Percentage of First Serves in Play

# %%
sns.histplot(df_matchstats2['w_%1stServesIn'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='w_%1stServesIn', ylabel='Count'>

# %%
sns.histplot(df_matchstats2['l_%1stServesIn'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='l_%1stServesIn', ylabel='Count'>

# %% [markdown]
# ## 3. df_BO5

# %%
#Import df_BO5
df_BO5 = pd.read_pickle(os.path.join(path, 'Prepared Data','Subsets','df_BO5.pkl'))

# %%
#check head
df_BO5.head()
# Out:
#       tourney_id  Year     tourney_name surface tourney_level winner_id  \
# 85972   1991-580  1991  Australian Open    Hard             G    101222
# 85973   1991-580  1991  Australian Open    Hard             G    100995
# 85974   1991-580  1991  Australian Open    Hard             G    101138
# 85975   1991-580  1991  Australian Open    Hard             G    100870
# 85976   1991-580  1991  Australian Open    Hard             G    101731
#
#       winner_ioc           winner_name  winner_age  winner_rank loser_id  \
# 85972        SWE         Stefan Edberg        24.9          1.0   101432
# 85973        BEL         Eduardo Masso        27.0        124.0   101242
# 85974        AUS              Pat Cash        25.6         84.0   101120
# 85975        RSA  Christo Van Rensburg        28.2         59.0   101256
# 85976        POR          Nuno Marques        20.7        104.0   101416
#
#       loser_ioc        loser_name  loser_rank  loser_age best_of round  \
# 85972       UKR  Dimitri Poliakov       162.0       22.9       5  R128
# 85973       USA       Brad Pearce        81.0       24.8       5  R128
# 85974       CZE     Karel Novacek        32.0       25.7       5  R128
# 85975       AUS    Mark Kratzmann        82.0       24.6       5  R128
# 85976       POR  Joao Cunha Silva       116.0       23.1       5  R128
#
#        minutes  w_#ServeGames  w_#aces  w_#dfs  w_#ServePoints  \
# 85972    114.0           13.0      2.0     3.0            94.0
# 85973    220.0           28.0      4.0     2.0           186.0
# 85974    110.0           13.0      2.0     3.0            82.0
# 85975    117.0           14.0      4.0     3.0            76.0
# 85976    178.0           23.0      1.0     2.0           133.0
#
#        w_#1stServesIn  w_#2ndServePoints  w_%1stServesIn  w_#1stWon  \
# 85972            71.0               23.0              75       53.0
# 85973           145.0               41.0              77       89.0
# 85974            54.0               28.0              65       36.0
# 85975            44.0               32.0              57       33.0
# 85976           100.0               33.0              75       73.0
#
#        w_%1stWon  w_#2ndWon  w_%2ndWon  w_bpSaved  w_#bpFaced  l_#ServeGames  \
# 85972         74        9.0         39        6.0         7.0           14.0
# 85973         61       27.0         65        8.0        15.0           26.0
# 85974         66       18.0         64        5.0         7.0           12.0
# 85975         75       22.0         68        2.0         4.0           14.0
# 85976         73       16.0         48        7.0        11.0           23.0
#
#        l_#aces  l_#dfs  l_#ServePoints  l_#1stServesIn  l_#2ndServePoints  \
# 85972      1.0     2.0           104.0            72.0               32.0
# 85973      1.0     5.0           177.0           110.0               67.0
# 85974      1.0     1.0            87.0            59.0               28.0
# 85975      2.0     4.0           101.0            49.0               52.0
# 85976      2.0     3.0           126.0            77.0               49.0
#
#        l_%1stServesIn  l_#1stWon  l_%1stWon  l_#2ndWon  l_%2ndWon  l_bpSaved  \
# 85972              69       43.0         59       11.0         34        4.0
# 85973              62       67.0         60       29.0         43        7.0
# 85974              67       31.0         52       12.0         42        9.0
# 85975              48       26.0         53       26.0         50        8.0
# 85976              61       57.0         74       28.0         57        9.0
#
#        l_#bpFaced
# 85972        10.0
# 85973        18.0
# 85974        16.0
# 85975        15.0
# 85976        13.0

# %% [markdown]
# ### 3A. Cleaning

# %%
df_BO5.shape
# Out:
# (16410, 44)

# %%
df_BO5.columns
# Out:
# Index(['tourney_id', 'Year', 'tourney_name', 'surface', 'tourney_level',
#        'winner_id', 'winner_ioc', 'winner_name', 'winner_age', 'winner_rank',
#        'loser_id', 'loser_ioc', 'loser_name', 'loser_rank', 'loser_age',
#        'best_of', 'round', 'minutes', 'w_#ServeGames', 'w_#aces', 'w_#dfs',
#        'w_#ServePoints', 'w_#1stServesIn', 'w_#2ndServePoints',
#        'w_%1stServesIn', 'w_#1stWon', 'w_%1stWon', 'w_#2ndWon', 'w_%2ndWon',
#        'w_bpSaved', 'w_#bpFaced', 'l_#ServeGames', 'l_#aces', 'l_#dfs',
#        'l_#ServePoints', 'l_#1stServesIn', 'l_#2ndServePoints',
#        'l_%1stServesIn', 'l_#1stWon', 'l_%1stWon', 'l_#2ndWon', 'l_%2ndWon',
#        'l_bpSaved', 'l_#bpFaced'],
#       dtype='object')

# %%
df_BO5.dtypes
# Out:
# tourney_id            object
# Year                  object
# tourney_name          object
# surface               object
# tourney_level         object
# winner_id             object
# winner_ioc            object
# winner_name           object
# winner_age           float64
# winner_rank          float64
# loser_id              object
# loser_ioc             object
# loser_name            object
# loser_rank           float64
# loser_age            float64
# best_of               object
# round                 object
# minutes              float64
# w_#ServeGames        float64
# w_#aces              float64
# w_#dfs               float64
# w_#ServePoints       float64
# w_#1stServesIn       float64
# w_#2ndServePoints    float64
# w_%1stServesIn         int64
# w_#1stWon            float64
# w_%1stWon              int64
# w_#2ndWon            float64
# w_%2ndWon              int64
# w_bpSaved            float64
# w_#bpFaced           float64
# l_#ServeGames        float64
# l_#aces              float64
# l_#dfs               float64
# l_#ServePoints       float64
# l_#1stServesIn       float64
# l_#2ndServePoints    float64
# l_%1stServesIn         int64
# l_#1stWon            float64
# l_%1stWon              int64
# l_#2ndWon            float64
# l_%2ndWon              int64
# l_bpSaved            float64
# l_#bpFaced           float64
# dtype: object

# %%
# Check for missing values

df_BO5.isnull().sum() #will disregard data pertaining to 'winner_rank', 'loser_rank' and 'minutes'
# Out:
# tourney_id              0
# Year                    0
# tourney_name            0
# surface                 0
# tourney_level           0
# winner_id               0
# winner_ioc              0
# winner_name             0
# winner_age              0
# winner_rank            43
# loser_id                0
# loser_ioc               0
# loser_name              0
# loser_rank             88
# loser_age               1
# best_of                 0
# round                   0
# minutes              1569
# w_#ServeGames           0
# w_#aces                 0
# w_#dfs                  0
# w_#ServePoints          0
# w_#1stServesIn          0
# w_#2ndServePoints       0
# w_%1stServesIn          0
# w_#1stWon               0
# w_%1stWon               0
# w_#2ndWon               0
# w_%2ndWon               0
# w_bpSaved               0
# w_#bpFaced              0
# l_#ServeGames           0
# l_#aces                 0
# l_#dfs                  0
# l_#ServePoints          0
# l_#1stServesIn          0
# l_#2ndServePoints       0
# l_%1stServesIn          0
# l_#1stWon               0
# l_%1stWon               0
# l_#2ndWon               0
# l_%2ndWon               0
# l_bpSaved               0
# l_#bpFaced              0
# dtype: int64

# %%
# Find duplicates

df_dups_BO5 = df_BO5[df_BO5.duplicated()]

# %%
df_dups_BO5.shape #no duplicates
# Out:
# (0, 44)

# %%
for col in df_BO5.columns.tolist():
      weird = (df_BO5[[col]].applymap(type) != df_BO5[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df_BO5[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %% [markdown]
# ### 3B. Correlation Heatmap

# %%
#create subset: drop irrelevant variables (same as in Section 2B for df_matchstats)

df_BO5_1 = df_BO5.drop(columns = ['tourney_id',
                                  'Year',
                                  'tourney_name',
                                  'surface',
                                  'tourney_level',
                                  'winner_id',
                                  'winner_name',
                                  'winner_ioc',
                                  'winner_age',
                                  'winner_rank',
                                  'loser_id', 
                                  'loser_name',
                                  'loser_ioc',
                                  'loser_rank',
                                  'loser_age',
                                  'best_of',
                                  'round',
                                  'minutes',
                                  'w_#ServeGames', 
                                  'w_#aces',
                                  'w_#dfs',
                                  'w_#1stServesIn',
                                  'w_#2ndServePoints',
                                  'w_#1stWon',
                                  'w_#2ndWon',
                                  'w_bpSaved',
                                  'l_#ServeGames',
                                  'l_#aces',
                                  'l_#dfs',
                                  'l_#1stServesIn', 
                                  'l_#2ndServePoints', 
                                  'l_#1stWon',
                                  'l_#2ndWon',
                                  'l_bpSaved'])

# %%
df_BO5_1.corr()
# Out:
#                 w_#ServePoints  w_%1stServesIn  w_%1stWon  w_%2ndWon  \
# w_#ServePoints        1.000000       -0.063999  -0.346745  -0.394110
# w_%1stServesIn       -0.063999        1.000000  -0.142825   0.034176
# w_%1stWon            -0.346745       -0.142825   1.000000   0.101825
# w_%2ndWon            -0.394110        0.034176   0.101825   1.000000
# w_#bpFaced            0.708899       -0.097393  -0.595687  -0.464967
# l_#ServePoints        0.883849       -0.031855  -0.261049  -0.279225
# l_%1stServesIn        0.065468        0.171315   0.000555  -0.010415
# l_%1stWon             0.434042        0.000682   0.140719   0.002815
# l_%2ndWon             0.320334        0.003151   0.048232   0.033111
# l_#bpFaced            0.252682       -0.051070  -0.346829  -0.226042
#
#                 w_#bpFaced  l_#ServePoints  l_%1stServesIn  l_%1stWon  \
# w_#ServePoints    0.708899        0.883849        0.065468   0.434042
# w_%1stServesIn   -0.097393       -0.031855        0.171315   0.000682
# w_%1stWon        -0.595687       -0.261049        0.000555   0.140719
# w_%2ndWon        -0.464967       -0.279225       -0.010415   0.002815
# w_#bpFaced        1.000000        0.559009        0.006254   0.070391
# l_#ServePoints    0.559009        1.000000        0.048869   0.392262
# l_%1stServesIn    0.006254        0.048869        1.000000  -0.163294
# l_%1stWon         0.070391        0.392262       -0.163294   1.000000
# l_%2ndWon         0.092779        0.255775        0.077608   0.135775
# l_#bpFaced        0.382107        0.440603       -0.039383  -0.272604
#
#                 l_%2ndWon  l_#bpFaced
# w_#ServePoints   0.320334    0.252682
# w_%1stServesIn   0.003151   -0.051070
# w_%1stWon        0.048232   -0.346829
# w_%2ndWon        0.033111   -0.226042
# w_#bpFaced       0.092779    0.382107
# l_#ServePoints   0.255775    0.440603
# l_%1stServesIn   0.077608   -0.039383
# l_%1stWon        0.135775   -0.272604
# l_%2ndWon        1.000000   -0.189568
# l_#bpFaced      -0.189568    1.000000

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(df_BO5_1.corr())
plt.show()

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(df_BO5_1.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df_BO5_1.corr(), fignum=f.number) # type of plot
plt.xticks(range(df_BO5_1.shape[1]), df_BO5_1, fontsize=12, rotation=90) # x axis labels
plt.yticks(range(df_BO5_1.shape[1]), df_BO5_1.columns, fontsize=12) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Serve Stats in Best of 5 Matches', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Serve Stats in Best of 5 Matches')

# %% [markdown]
# ### 3C. Scatterplots

# %%
# Create a scatterplot for the "w_#bpFaced" columns in seaborn

sns.lmplot(x = 'w_%1stWon', y = 'w_#bpFaced', data = df_BO5_1)
# Out:
# /Users/tristansavella/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "l_#bpFaced" columns in seaborn

sns.lmplot(x = 'l_%1stWon', y = 'l_#bpFaced', data = df_BO5_1)
# Out:
# /Users/tristansavella/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 3D. Pairplot

# %%
# Keep only the variables you want to use in the pair plot

df_BO5_pairplot = df_BO5[['w_%1stWon', 'w_%1stServesIn', 'w_%2ndWon','w_#bpFaced']]

# %%
# Create a pair plot 

g = sns.pairplot(df_BO5_pairplot)
# Out:
# /Users/tristansavella/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 3E. Categorical Plot

# %%
df_BO5.describe()
# Out:
#          winner_age   winner_rank    loser_rank     loser_age       minutes  \
# count  16410.000000  16367.000000  16322.000000  16409.000000  14841.000000
# mean      26.075850     54.814871     95.077441     26.141368    145.429958
# std        3.844686     79.592387    119.612068      3.930155     48.387828
# min       16.200000      1.000000      1.000000     15.800000      1.000000
# 25%       23.200000     11.000000     36.000000     23.200000    110.000000
# 50%       25.800000     32.000000     71.000000     25.900000    139.000000
# 75%       28.700000     73.000000    110.000000     28.800000    177.000000
# max       40.800000   1774.000000   2147.000000     42.500000    665.000000
#
#        w_#ServeGames       w_#aces        w_#dfs  w_#ServePoints  \
# count   16410.000000  16410.000000  16410.000000    16410.000000
# mean       17.658196      9.649482      3.872943      112.210664
# std         4.757280      6.893326      2.962994       35.205910
# min         0.000000      0.000000      0.000000        4.000000
# 25%        14.000000      5.000000      2.000000       85.000000
# 50%        17.000000      8.000000      3.000000      108.000000
# 75%        21.000000     13.000000      5.000000      136.000000
# max        90.000000    113.000000     26.000000      491.000000
#
#        w_#1stServesIn  w_#2ndServePoints  w_%1stServesIn     w_#1stWon  \
# count    16410.000000       16410.000000    16410.000000  16410.000000
# mean        69.290250          42.920414       61.421207     52.689701
# std         22.914444          16.397007        7.574686     16.280657
# min          2.000000           1.000000       34.000000      2.000000
# 25%         52.000000          31.000000       56.000000     41.000000
# 50%         66.000000          41.000000       61.000000     51.000000
# 75%         84.000000          53.000000       66.000000     63.000000
# max        361.000000         130.000000       98.000000    292.000000
#
#           w_%1stWon     w_#2ndWon     w_%2ndWon     w_bpSaved    w_#bpFaced  \
# count  16410.000000  16410.000000  16410.000000  16410.000000  16410.000000
# mean      76.532724     23.122425     54.690494      4.884522      7.217246
# std        7.475521      8.271054      9.644750      3.769763      5.096321
# min       33.000000      0.000000      0.000000      0.000000      0.000000
# 25%       71.000000     17.000000     48.000000      2.000000      3.000000
# 50%       76.000000     22.000000     54.000000      4.000000      6.000000
# 75%       82.000000     28.000000     61.000000      7.000000     10.000000
# max      100.000000     82.000000    129.000000     24.000000     34.000000
#
#        l_#ServeGames       l_#aces        l_#dfs  l_#ServePoints  \
# count   16410.000000  16410.000000  16410.000000    16410.000000
# mean       17.387812      7.021146      4.867215      117.011030
# std         4.791909      6.169383      3.207794       33.939756
# min         0.000000      0.000000      0.000000        5.000000
# 25%        14.000000      3.000000      3.000000       92.000000
# 50%        17.000000      5.000000      4.000000      113.000000
# 75%        21.000000     10.000000      7.000000      140.000000
# max        91.000000    103.000000     26.000000      489.000000
#
#        l_#1stServesIn  l_#2ndServePoints  l_%1stServesIn     l_#1stWon  \
# count    16410.000000       16410.000000    16410.000000  16410.000000
# mean        70.275929          46.735101       59.470201     47.172456
# std         22.707925          15.913750        7.686186     17.734154
# min          2.000000           1.000000       25.000000      1.000000
# 25%         54.000000          35.000000       54.000000     34.000000
# 50%         67.000000          45.000000       60.000000     45.000000
# 75%         84.000000          56.000000       64.000000     58.000000
# max        328.000000         161.000000       97.000000    284.000000
#
#           l_%1stWon     l_#2ndWon     l_%2ndWon     l_bpSaved    l_#bpFaced
# count  16410.000000  16410.000000  16410.000000  16410.000000  16410.000000
# mean      65.850640     21.044851     44.052163      6.860695     12.284278
# std        8.647874      8.697526      9.125039      3.841246      4.712147
# min       11.000000      0.000000      0.000000     -6.000000      0.000000
# 25%       60.000000     15.000000     38.000000      4.000000      9.000000
# 50%       66.000000     20.000000     44.000000      6.000000     12.000000
# 75%       72.000000     27.000000     50.000000      9.000000     15.000000
# max      100.000000    101.000000    100.000000     28.000000     35.000000

# %% [markdown]
# ### Percentage of First Serve Points Won

# %%
# Use a histogram to visualize the distribution of the variables. 
# winner first serve points won
sns.histplot(df_BO5['w_%1stWon'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='w_%1stWon', ylabel='Count'>

# %%
#loser 1st serve points won
sns.histplot(df_BO5['l_%1stWon'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='l_%1stWon', ylabel='Count'>

# %% [markdown]
# ### Percentage of second serve points won

# %%
#winner 2nd serve points won
sns.histplot(df_BO5['w_%2ndWon'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='w_%2ndWon', ylabel='Count'>

# %%
#loser 2nd serve points won
sns.histplot(df_BO5['l_%2ndWon'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='l_%2ndWon', ylabel='Count'>

# %% [markdown]
# ### Percentage of First Serves in Play

# %%
#winner 1st Serve Percentage
sns.histplot(df_BO5['w_%1stServesIn'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='w_%1stServesIn', ylabel='Count'>

# %%
#loser 1st Serve Percentage
sns.histplot(df_BO5['l_%1stServesIn'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='l_%1stServesIn', ylabel='Count'>

# %% [markdown]
# ### 3 df_BO3

# %% [markdown]
# ### 3A. Cleaning

# %%
#Import df_BO3
df_BO3 = pd.read_pickle(os.path.join(path, 'Prepared Data','Subsets','df_BO3.pkl'))

# %%
df_BO3.head()
# Out:
#       tourney_id  Year tourney_name surface tourney_level winner_id  \
# 85848   1991-339  1990     Adelaide    Hard             A    101723
# 85849   1991-339  1990     Adelaide    Hard             A    100946
# 85850   1991-339  1990     Adelaide    Hard             A    101234
# 85851   1991-339  1990     Adelaide    Hard             A    101889
# 85852   1991-339  1990     Adelaide    Hard             A    101274
#
#       winner_ioc           winner_name  winner_age  winner_rank loser_id  \
# 85848        SWE        Magnus Larsson        20.7         56.0   101414
# 85849        YUG  Slobodan Zivojinovic        27.4        304.0   101256
# 85850        GER         Patrik Kuhnen        24.8         82.0   101421
# 85851        AUS       Todd Woodbridge        19.7         50.0   101703
# 85852        GER         Udo Riglewski        24.4         88.0   101843
#
#       loser_ioc       loser_name  loser_rank  loser_age best_of round  \
# 85848       GER     Boris Becker         2.0       23.1       3   R32
# 85849       AUS   Mark Kratzmann        75.0       24.6       3   R32
# 85850       FIN   Veli Paloheimo        69.0       23.0       3   R32
# 85851       FRA  Guillaume Raoux        84.0       20.8       3   R32
# 85852       ESP   Sergi Bruguera        28.0       19.9       3   R32
#
#        minutes  w_#ServeGames  w_#aces  w_#dfs  w_#ServePoints  \
# 85848    130.0           15.0      6.0     2.0            96.0
# 85849    119.0           15.0     19.0     4.0           101.0
# 85850     71.0            8.0      6.0     1.0            54.0
# 85851     85.0            9.0      2.0     0.0            60.0
# 85852     90.0           10.0      4.0     2.0            72.0
#
#        w_#1stServesIn  w_#2ndServePoints  w_%1stServesIn  w_#1stWon  \
# 85848            55.0               41.0              57       39.0
# 85849            56.0               45.0              55       45.0
# 85850            31.0               23.0              57       24.0
# 85851            40.0               20.0              66       30.0
# 85852            40.0               32.0              55       33.0
#
#        w_%1stWon  w_#2ndWon  w_%2ndWon  w_bpSaved  w_#bpFaced  l_#ServeGames  \
# 85848         70       25.0         60        2.0         4.0           16.0
# 85849         80       25.0         55        9.0        10.0           15.0
# 85850         77       13.0         56        1.0         1.0            8.0
# 85851         75       14.0         70        3.0         3.0           10.0
# 85852         82       14.0         43        7.0         8.0           11.0
#
#        l_#aces  l_#dfs  l_#ServePoints  l_#1stServesIn  l_#2ndServePoints  \
# 85848      8.0     3.0            95.0            62.0               33.0
# 85849      8.0     2.0            84.0            41.0               43.0
# 85850      2.0     2.0            60.0            37.0               23.0
# 85851      3.0     3.0            74.0            45.0               29.0
# 85852      2.0     2.0            77.0            41.0               36.0
#
#        l_%1stServesIn  l_#1stWon  l_%1stWon  l_#2ndWon  l_%2ndWon  l_bpSaved  \
# 85848              65       44.0         70       23.0         69        6.0
# 85849              48       35.0         85       27.0         62        1.0
# 85850              61       22.0         59        6.0         26        4.0
# 85851              60       30.0         66       11.0         37        5.0
# 85852              53       28.0         68       15.0         41        4.0
#
#        l_#bpFaced
# 85848         8.0
# 85849         2.0
# 85850         8.0
# 85851         8.0
# 85852         8.0

# %% [markdown]
# ### 3B. Correlation Heatmap

# %%
#create subset: drop irrelevant variables (same as in Section 2B for df_matchstats)

df_BO3_1 = df_BO3.drop(columns = ['tourney_id',
                                  'Year',
                                  'tourney_name',
                                  'surface',
                                  'tourney_level',
                                  'winner_id',
                                  'winner_name',
                                  'winner_ioc',
                                  'winner_age',
                                  'winner_rank',
                                  'loser_id', 
                                  'loser_name',
                                  'loser_ioc',
                                  'loser_rank',
                                  'loser_age',
                                  'best_of',
                                  'round',
                                  'minutes',
                                  'w_#ServeGames', 
                                  'w_#aces',
                                  'w_#dfs',
                                  'w_#1stServesIn',
                                  'w_#2ndServePoints',
                                  'w_#1stWon',
                                  'w_#2ndWon',
                                  'w_bpSaved',
                                  'l_#ServeGames',
                                  'l_#aces',
                                  'l_#dfs',
                                  'l_#1stServesIn', 
                                  'l_#2ndServePoints', 
                                  'l_#1stWon',
                                  'l_#2ndWon',
                                  'l_bpSaved'])

# %%
df_BO3_1.corr()
# Out:
#                 w_#ServePoints  w_%1stServesIn  w_%1stWon  w_%2ndWon  \
# w_#ServePoints        1.000000       -0.039654  -0.363886  -0.350029
# w_%1stServesIn       -0.039654        1.000000  -0.163561   0.005307
# w_%1stWon            -0.363886       -0.163561   1.000000   0.085733
# w_%2ndWon            -0.350029        0.005307   0.085733   1.000000
# w_#bpFaced            0.684689       -0.068601  -0.554432  -0.450615
# l_#ServePoints        0.830801       -0.015188  -0.229955  -0.219030
# l_%1stServesIn        0.077334        0.125684  -0.010268  -0.009566
# l_%1stWon             0.384199       -0.000036   0.165394   0.070718
# l_%2ndWon             0.346355        0.001640   0.088271   0.013431
# l_#bpFaced            0.165469       -0.039114  -0.301680  -0.210247
#
#                 w_#bpFaced  l_#ServePoints  l_%1stServesIn  l_%1stWon  \
# w_#ServePoints    0.684689        0.830801        0.077334   0.384199
# w_%1stServesIn   -0.068601       -0.015188        0.125684  -0.000036
# w_%1stWon        -0.554432       -0.229955       -0.010268   0.165394
# w_%2ndWon        -0.450615       -0.219030       -0.009566   0.070718
# w_#bpFaced        1.000000        0.478239        0.018621   0.014680
# l_#ServePoints    0.478239        1.000000        0.071245   0.319532
# l_%1stServesIn    0.018621        0.071245        1.000000  -0.156857
# l_%1stWon         0.014680        0.319532       -0.156857   1.000000
# l_%2ndWon         0.058713        0.279595        0.042888   0.132196
# l_#bpFaced        0.309297        0.407737       -0.030584  -0.310983
#
#                 l_%2ndWon  l_#bpFaced
# w_#ServePoints   0.346355    0.165469
# w_%1stServesIn   0.001640   -0.039114
# w_%1stWon        0.088271   -0.301680
# w_%2ndWon        0.013431   -0.210247
# w_#bpFaced       0.058713    0.309297
# l_#ServePoints   0.279595    0.407737
# l_%1stServesIn   0.042888   -0.030584
# l_%1stWon        0.132196   -0.310983
# l_%2ndWon        1.000000   -0.224186
# l_#bpFaced      -0.224186    1.000000

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(df_BO3_1.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df_BO3_1.corr(), fignum=f.number) # type of plot
plt.xticks(range(df_BO3_1.shape[1]), df_BO3_1, fontsize=12, rotation=90) # x axis labels
plt.yticks(range(df_BO3_1.shape[1]), df_BO3_1.columns, fontsize=12) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Serve Stats in Best of 3 Matches', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Serve Stats in Best of 3 Matches')

# %% [markdown]
# ## 4. df_grass
# #### 4a. Cleaning
# #### 4b. Correlation Heatmap
# #### 4c. Scatterplot
# #### 4d. Pair Plot
# #### 4e. Categorical Plot

# %%
#Import df_grass
df_grass = pd.read_pickle(os.path.join(path, 'Prepared Data','Subsets','df_grass.pkl'))

# %%
df_grass.head()
# Out:
#       tourney_id  Year  tourney_name surface tourney_level winner_id  \
# 87645   1991-311  1991  Queen's Club   Grass             A    101589
# 87646   1991-311  1991  Queen's Club   Grass             A    101727
# 87647   1991-311  1991  Queen's Club   Grass             A    101106
# 87648   1991-311  1991  Queen's Club   Grass             A    100529
# 87649   1991-311  1991  Queen's Club   Grass             A    101138
#
#       winner_ioc        winner_name  winner_age  winner_rank loser_id  \
# 87645        FRA     Arnaud Boetsch        22.1        125.0   100967
# 87646        AUS  Jason Stoltenberg        21.1        103.0   101256
# 87647        SWE     Peter Lundgren        26.3         67.0   101421
# 87648        USA       Kevin Curren        33.2         53.0   101150
# 87649        AUS           Pat Cash        26.0         77.0   101413
#
#       loser_ioc        loser_name  loser_rank  loser_age best_of round  \
# 87645       USA        Dan Goldie       120.0       27.6       3   R64
# 87646       AUS    Mark Kratzmann       147.0       25.0       3   R64
# 87647       FIN    Veli Paloheimo        64.0       23.4       3   R64
# 87648       ITA    Gianluca Pozzi       190.0       25.9       3   R64
# 87649       PHI  Felix Barrientos       194.0       23.5       3   R64
#
#        minutes  w_#ServeGames  w_#aces  w_#dfs  w_#ServePoints  \
# 87645    108.0           15.0      5.0     1.0           100.0
# 87646     63.0            9.0      6.0     1.0            42.0
# 87647     76.0           10.0      2.0     2.0            70.0
# 87648     82.0           12.0      6.0     1.0            61.0
# 87649     72.0            9.0      5.0     3.0            55.0
#
#        w_#1stServesIn  w_#2ndServePoints  w_%1stServesIn  w_#1stWon  \
# 87645            55.0               45.0              55       40.0
# 87646            28.0               14.0              66       25.0
# 87647            45.0               25.0              64       35.0
# 87648            39.0               22.0              63       28.0
# 87649            29.0               26.0              52       24.0
#
#        w_%1stWon  w_#2ndWon  w_%2ndWon  w_bpSaved  w_#bpFaced  l_#ServeGames  \
# 87645         72       20.0         44       11.0        15.0           15.0
# 87646         89       11.0         78        0.0         0.0            8.0
# 87647         77       12.0         48       10.0        11.0           10.0
# 87648         71       16.0         72        0.0         1.0           13.0
# 87649         82       15.0         57        2.0         2.0            8.0
#
#        l_#aces  l_#dfs  l_#ServePoints  l_#1stServesIn  l_#2ndServePoints  \
# 87645      5.0    11.0           106.0            60.0               46.0
# 87646      3.0     2.0            67.0            31.0               36.0
# 87647      8.0     3.0            74.0            42.0               32.0
# 87648      5.0     5.0            77.0            46.0               31.0
# 87649      1.0     4.0            55.0            35.0               20.0
#
#        l_%1stServesIn  l_#1stWon  l_%1stWon  l_#2ndWon  l_%2ndWon  l_bpSaved  \
# 87645              56       37.0         61       19.0         41       11.0
# 87646              46       19.0         61       16.0         44        7.0
# 87647              56       29.0         69       15.0         46        5.0
# 87648              59       26.0         56       18.0         58        5.0
# 87649              63       23.0         65        7.0         35        1.0
#
#        l_#bpFaced
# 87645        17.0
# 87646        10.0
# 87647         8.0
# 87648         9.0
# 87649         4.0

# %% [markdown]
# ### 4a. Cleaning

# %%
df_grass.shape
# Out:
# (9457, 44)

# %%
df_grass.columns
# Out:
# Index(['tourney_id', 'Year', 'tourney_name', 'surface', 'tourney_level',
#        'winner_id', 'winner_ioc', 'winner_name', 'winner_age', 'winner_rank',
#        'loser_id', 'loser_ioc', 'loser_name', 'loser_rank', 'loser_age',
#        'best_of', 'round', 'minutes', 'w_#ServeGames', 'w_#aces', 'w_#dfs',
#        'w_#ServePoints', 'w_#1stServesIn', 'w_#2ndServePoints',
#        'w_%1stServesIn', 'w_#1stWon', 'w_%1stWon', 'w_#2ndWon', 'w_%2ndWon',
#        'w_bpSaved', 'w_#bpFaced', 'l_#ServeGames', 'l_#aces', 'l_#dfs',
#        'l_#ServePoints', 'l_#1stServesIn', 'l_#2ndServePoints',
#        'l_%1stServesIn', 'l_#1stWon', 'l_%1stWon', 'l_#2ndWon', 'l_%2ndWon',
#        'l_bpSaved', 'l_#bpFaced'],
#       dtype='object')

# %%
df_grass.dtypes
# Out:
# tourney_id            object
# Year                  object
# tourney_name          object
# surface               object
# tourney_level         object
# winner_id             object
# winner_ioc            object
# winner_name           object
# winner_age           float64
# winner_rank          float64
# loser_id              object
# loser_ioc             object
# loser_name            object
# loser_rank           float64
# loser_age            float64
# best_of               object
# round                 object
# minutes              float64
# w_#ServeGames        float64
# w_#aces              float64
# w_#dfs               float64
# w_#ServePoints       float64
# w_#1stServesIn       float64
# w_#2ndServePoints    float64
# w_%1stServesIn         int64
# w_#1stWon            float64
# w_%1stWon              int64
# w_#2ndWon            float64
# w_%2ndWon              int64
# w_bpSaved            float64
# w_#bpFaced           float64
# l_#ServeGames        float64
# l_#aces              float64
# l_#dfs               float64
# l_#ServePoints       float64
# l_#1stServesIn       float64
# l_#2ndServePoints    float64
# l_%1stServesIn         int64
# l_#1stWon            float64
# l_%1stWon              int64
# l_#2ndWon            float64
# l_%2ndWon              int64
# l_bpSaved            float64
# l_#bpFaced           float64
# dtype: object

# %%
# Check for missing values

df_grass.isnull().sum() #will disregard data pertaining to 'winner_rank', 'loser_rank' and 'minutes'
# Out:
# tourney_id             0
# Year                   0
# tourney_name           0
# surface                0
# tourney_level          0
# winner_id              0
# winner_ioc             0
# winner_name            0
# winner_age             0
# winner_rank           42
# loser_id               0
# loser_ioc              0
# loser_name             0
# loser_rank            53
# loser_age              1
# best_of                0
# round                  0
# minutes              524
# w_#ServeGames          0
# w_#aces                0
# w_#dfs                 0
# w_#ServePoints         0
# w_#1stServesIn         0
# w_#2ndServePoints      0
# w_%1stServesIn         0
# w_#1stWon              0
# w_%1stWon              0
# w_#2ndWon              0
# w_%2ndWon              0
# w_bpSaved              0
# w_#bpFaced             0
# l_#ServeGames          0
# l_#aces                0
# l_#dfs                 0
# l_#ServePoints         0
# l_#1stServesIn         0
# l_#2ndServePoints      0
# l_%1stServesIn         0
# l_#1stWon              0
# l_%1stWon              0
# l_#2ndWon              0
# l_%2ndWon              0
# l_bpSaved              0
# l_#bpFaced             0
# dtype: int64

# %%
# Find duplicates

df_dups_grass = df_grass[df_grass.duplicated()]

# %%
df_dups_grass.shape #no duplicates
# Out:
# (0, 44)

# %%
for col in df_BO5.columns.tolist():
      weird = (df_grass[[col]].applymap(type) != df_grass[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df_grass[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %% [markdown]
# ### 4B. Correlation Heatmap

# %%
#create subset: drop irrelevant variables (same as in Section 2B for df_matchstats)

df_grass_1 = df_grass.drop(columns = ['tourney_id',
                                  'Year',
                                  'tourney_name',
                                  'surface',
                                  'tourney_level',
                                  'winner_id',
                                  'winner_name',
                                  'winner_ioc',
                                  'winner_age',
                                  'winner_rank',
                                  'loser_id', 
                                  'loser_name',
                                  'loser_ioc',
                                  'loser_rank',
                                  'loser_age',
                                  'best_of',
                                  'round',
                                  'minutes',
                                  'w_#ServeGames', 
                                  'w_#aces',
                                  'w_#dfs',
                                  'w_#1stServesIn',
                                  'w_#2ndServePoints',
                                  'w_#1stWon',
                                  'w_#2ndWon',
                                  'w_bpSaved',
                                  'l_#ServeGames',
                                  'l_#aces',
                                  'l_#dfs',
                                  'l_#1stServesIn', 
                                  'l_#2ndServePoints', 
                                  'l_#1stWon',
                                  'l_#2ndWon',
                                  'l_bpSaved'])

# %%
df_grass_1.corr()
# Out:
#                 w_#ServePoints  w_%1stServesIn  w_%1stWon  w_%2ndWon  \
# w_#ServePoints        1.000000        0.017959  -0.248716  -0.318120
# w_%1stServesIn        0.017959        1.000000  -0.077427   0.033670
# w_%1stWon            -0.248716       -0.077427   1.000000   0.074726
# w_%2ndWon            -0.318120        0.033670   0.074726   1.000000
# w_#bpFaced            0.667037       -0.102536  -0.524635  -0.443522
# l_#ServePoints        0.915720        0.046355  -0.150758  -0.211922
# l_%1stServesIn        0.113004        0.189437   0.015342   0.046369
# l_%1stWon             0.331141        0.041592   0.106752   0.039822
# l_%2ndWon             0.198354        0.072707   0.076423   0.061062
# l_#bpFaced            0.374445       -0.035228  -0.218274  -0.205499
#
#                 w_#bpFaced  l_#ServePoints  l_%1stServesIn  l_%1stWon  \
# w_#ServePoints    0.667037        0.915720        0.113004   0.331141
# w_%1stServesIn   -0.102536        0.046355        0.189437   0.041592
# w_%1stWon        -0.524635       -0.150758        0.015342   0.106752
# w_%2ndWon        -0.443522       -0.211922        0.046369   0.039822
# w_#bpFaced        1.000000        0.528240        0.013147   0.054834
# l_#ServePoints    0.528240        1.000000        0.103611   0.263868
# l_%1stServesIn    0.013147        0.103611        1.000000  -0.098122
# l_%1stWon         0.054834        0.263868       -0.098122   1.000000
# l_%2ndWon         0.018601        0.131064        0.086782   0.124111
# l_#bpFaced        0.369239        0.541584       -0.042384  -0.276702
#
#                 l_%2ndWon  l_#bpFaced
# w_#ServePoints   0.198354    0.374445
# w_%1stServesIn   0.072707   -0.035228
# w_%1stWon        0.076423   -0.218274
# w_%2ndWon        0.061062   -0.205499
# w_#bpFaced       0.018601    0.369239
# l_#ServePoints   0.131064    0.541584
# l_%1stServesIn   0.086782   -0.042384
# l_%1stWon        0.124111   -0.276702
# l_%2ndWon        1.000000   -0.259012
# l_#bpFaced      -0.259012    1.000000

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(df_grass_1.corr())
plt.show()

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(df_grass_1.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df_grass_1.corr(), fignum=f.number) # type of plot
plt.xticks(range(df_grass_1.shape[1]), df_grass_1, fontsize=12, rotation=90) # x axis labels
plt.yticks(range(df_grass_1.shape[1]), df_grass_1.columns, fontsize=12) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Serve Stats in Tennis Matches on Grass Courts', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Serve Stats in Tennis Matches on Grass Courts')

# %% [markdown]
# ### 4C. Scatterplots

# %%
# Create a scatterplot for the "availability_365" and "price per unit" columns in seaborn

sns.lmplot(x = 'w_%1stWon', y = 'w_#bpFaced', data = df_grass_1)
# Out:
# /Users/tristansavella/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 4D. Pairplots

# %%
# Keep only the variables you want to use in the pair plot

df_grass_pairplot = df_grass[['w_%1stWon', 'w_%1stServesIn', 'w_%2ndWon','w_#bpFaced']]

# %%
# Create a pair plot 

g = sns.pairplot(df_grass_pairplot)
# Out:
# /Users/tristansavella/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 4E. Categorical Plots
